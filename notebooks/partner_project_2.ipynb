# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
colors = ["#7CAD5", "#EF412A", "#7099E9", "#777776"]

# %%
colors2 = ["#B1301F", "#EF412A", "#343434", "#777776", "#C7CAD5", "#7099E9", "#415A8C", "#161616"]

# %%
dict_df = pd.read_excel('c:/Users/KMGre/Documents/DA8/Projects/teis_da8_1-new-balance-and-grill/data/TEIS_IFSP_Teaming_Jan_2022-_Jan_2023.xlsx', 
                   sheet_name=['All Children with IFSPs','Compiled_IFSP Teaming'])


all_child_df = dict_df .get('All Children with IFSPs')
compiled_ifsp_df = dict_df.get('Compiled_IFSP Teaming')


all_child_df
compiled_ifsp_df
# Out:
# C:\Users\KMGre\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#       CHILD_ID SERVICE_DATE START_TIME  END_TIME  SERVICE_SETTING  \
# 0       457136   2022-01-21   09:30:00  10:30:00  Community-based
# 1       457136   2022-02-15   14:00:00  15:00:00  Community-based
# 2       457585   2022-01-24   08:30:00  09:30:00       Telehealth
# 3       457852   2022-01-12   14:00:00  15:00:00  Community-based
# 4       458051   2022-01-12   12:00:00  13:00:00       Telehealth
# ...        ...          ...        ...       ...              ...
# 9538    541337   2023-01-10   15:00:00  16:00:00             Home
# 9539    541511   2023-01-19   13:30:00  14:30:00             Home
# 9540    541890   2023-01-19   09:00:00  10:00:00             Home
# 9541    542077   2023-01-30   14:30:00  15:20:00       Telehealth
# 9542    542122   2023-01-30   13:00:00  14:00:00             Home
#
#        SERVICE DELIVERY          ADD_USER            ADD_DATE  \
# 0     Service Delivered         LEECAROL1 2022-01-21 17:54:45
# 1     Service Delivered         LEECAROL1 2022-02-16 05:29:12
# 2     Service Delivered  MILLARDCATHERINE 2022-01-24 14:18:29
# 3     Service Delivered       HEMELKATIE1 2022-01-18 10:39:51
# 4     Service Delivered        JONESMEGAN 2022-01-12 13:46:48
# ...                 ...               ...                 ...
# 9538  Service Delivered           WESTAMY 2023-01-12 17:55:59
# 9539  Service Delivered           WESTAMY 2023-01-20 16:11:04
# 9540  Service Delivered           WESTAMY 2023-01-20 10:23:05
# 9541  Service Delivered   FANELLASAMANTHA 2023-01-30 15:21:59
# 9542  Service Delivered        QUINNEMILY 2023-02-02 21:54:53
#
#      IFSP Teaming ID name                         Agency Name Agency Type  \
# 0             IEP Meeting  Siskin Children's Institute (EIRA)        EIRA
# 1                Co-Visit  Siskin Children's Institute (EIRA)        EIRA
# 2             IEP Meeting  Siskin Children's Institute (EIRA)        EIRA
# 3             IEP Meeting                               LTVEC        EIRA
# 4            IFSP Meeting             First Steps, Inc (EIRA)        EIRA
# ...                   ...                                 ...         ...
# 9538             Co-Visit                  Kid's Putnam, Inc.        EIRA
# 9539             Co-Visit                  Kid's Putnam, Inc.        EIRA
# 9540             Co-Visit                  Kid's Putnam, Inc.        EIRA
# 9541         IFSP Meeting           Pediatric Language Clinic        EIRA
# 9542             Co-Visit  Little Folks Arc of Washington Co.        EIRA
#
#                             Service Name
# 0     Dev. Therapy Prof - Home/Community
# 1     Dev. Therapy Prof - Home/Community
# 2     Dev. Therapy Prof - Home/Community
# 3     Dev. Therapy Prof - Home/Community
# 4     Dev. Therapy Prof - Home/Community
# ...                                  ...
# 9538  Dev. Therapy Prof - Home/Community
# 9539  Dev. Therapy Prof - Home/Community
# 9540  Dev. Therapy Prof - Home/Community
# 9541  Dev. Therapy Prof - Home/Community
# 9542  Dev. Therapy Prof - Home/Community
#
# [9543 rows x 12 columns]

# %%
all_child_df
# Out:
#        POE  Child ID Referral Date  Exit Date
# 0       ET    508615    2021-08-06        NaT
# 1       ET    488455    2021-11-02        NaT
# 2       ET    494500    2020-12-14        NaT
# 3       ET    515143    2021-11-22        NaT
# 4       ET    505490    2021-06-15        NaT
# ...     ..       ...           ...        ...
# 138659  UC    539845    2022-11-03        NaT
# 138660  UC    499575    2021-03-11        NaT
# 138661  UC    540987    2022-11-16        NaT
# 138662  UC    526430    2022-07-19 2023-02-13
# 138663  UC    545101    2023-01-17        NaT
#
# [138664 rows x 4 columns]

# %% [markdown]
# Analysis Questions:
# 1. How many children are receiving co-visits? What is the rate of co-visits? That is, out of children how have an IFSP, how many are receiving co-visits?

# %%
q1_df = compiled_ifsp_df[compiled_ifsp_df["IFSP Teaming ID name"] == 'Co-Visit']
q1_df1 = q1_df[q1_df["SERVICE DELIVERY"] == 'Service Delivered']
q1_df2 = q1_df1[q1_df1["SERVICE_DATE"] < '2023-01-01']
q1_df2
# Out:
#       CHILD_ID SERVICE_DATE START_TIME  END_TIME  SERVICE_SETTING  \
# 1       457136   2022-02-15   14:00:00  15:00:00  Community-based
# 6       458850   2022-02-15   14:00:00  14:30:00       Telehealth
# 7       458851   2022-02-15   14:15:00  14:45:00       Telehealth
# 8       459167   2022-01-26   09:30:00  10:00:00       Telehealth
# 9       459167   2022-01-26   09:00:00  10:00:00       Telehealth
# ...        ...          ...        ...       ...              ...
# 9504    537193   2022-12-20   11:00:00  12:00:00             Home
# 9505    537193   2022-12-20   11:00:00  12:00:00             Home
# 9527    539820   2022-12-12   16:25:00  17:10:00  Community-based
# 9528    539820   2022-12-19   09:20:00  10:00:00  Community-based
# 9534    540001   2022-12-16   13:30:00  14:00:00             Home
#
#        SERVICE DELIVERY          ADD_USER            ADD_DATE  \
# 1     Service Delivered         LEECAROL1 2022-02-16 05:29:12
# 6     Service Delivered       BUCKCYNTHIA 2022-02-15 18:07:38
# 7     Service Delivered       BUCKCYNTHIA 2022-02-15 18:08:54
# 8     Service Delivered    HINESKONSTANCE 2022-01-26 11:08:06
# 9     Service Delivered    GLASSKATHERINE 2022-02-02 11:57:55
# ...                 ...               ...                 ...
# 9504  Service Delivered         THEOBALDD 2022-12-20 20:54:26
# 9505  Service Delivered    JOHNSTONNICOLE 2022-12-23 11:41:04
# 9527  Service Delivered  SCHNEIDERKATHRYN 2022-12-16 17:46:00
# 9528  Service Delivered  SCHNEIDERKATHRYN 2022-12-21 14:25:30
# 9534  Service Delivered     SCOTTKRISTINA 2022-12-16 16:25:15
#
#      IFSP Teaming ID name                                        Agency Name  \
# 1                Co-Visit                 Siskin Children's Institute (EIRA)
# 6                Co-Visit               Physical Therapy Services, PA (EIRA)
# 7                Co-Visit               Physical Therapy Services, PA (EIRA)
# 8                Co-Visit                   LeBonheur EI & Dev (LEAD) (EIRA)
# 9                Co-Visit                 LeBonheur EI & Dev (LEAD) (vendor)
# ...                   ...                                                ...
# 9504             Co-Visit                            Heightened Potential Co
# 9505             Co-Visit                                              LTVEC
# 9527             Co-Visit                 Little Folks Arc of Washington Co.
# 9528             Co-Visit                 Little Folks Arc of Washington Co.
# 9534             Co-Visit  Support Solutions of the Mid-South (CS Patterson)
#
#       Agency Type                        Service Name
# 1            EIRA  Dev. Therapy Prof - Home/Community
# 6            EIRA  Dev. Therapy Prof - Home/Community
# 7            EIRA  Dev. Therapy Prof - Home/Community
# 8            EIRA          Physical Therapy Assistant
# 9     Independent                      Speech Therapy
# ...           ...                                 ...
# 9504  Independent                Occupational Therapy
# 9505         EIRA  Dev. Therapy Prof - Home/Community
# 9527         EIRA  Dev. Therapy Prof - Home/Community
# 9528         EIRA  Dev. Therapy Prof - Home/Community
# 9534         EIRA  Dev. Therapy Prof - Home/Community
#
# [3695 rows x 12 columns]

# %%
q1_df['CHILD_ID'].nunique()
# Out:
# 1645

# %%
q1_df2['CHILD_ID'].nunique()
# Out:
# 1501

# %% [markdown]
# 1A. 1645 children have attempted to have a co visit and 1642 have actually recieved a co visit.

# %%
compiled_ifsp_df['IFSP Teaming ID name'].value_counts(normalize=True) * 100
# Out:
# IFSP Meeting    50.508226
# Co-Visit        42.869119
# IEP Meeting      6.622655
# Name: IFSP Teaming ID name, dtype: float64

# %%
q2_df = compiled_ifsp_df[compiled_ifsp_df["SERVICE DELIVERY"] == 'Service Delivered']
q2_df
# Out:
#       CHILD_ID SERVICE_DATE START_TIME  END_TIME  SERVICE_SETTING  \
# 0       457136   2022-01-21   09:30:00  10:30:00  Community-based
# 1       457136   2022-02-15   14:00:00  15:00:00  Community-based
# 2       457585   2022-01-24   08:30:00  09:30:00       Telehealth
# 3       457852   2022-01-12   14:00:00  15:00:00  Community-based
# 4       458051   2022-01-12   12:00:00  13:00:00       Telehealth
# ...        ...          ...        ...       ...              ...
# 9538    541337   2023-01-10   15:00:00  16:00:00             Home
# 9539    541511   2023-01-19   13:30:00  14:30:00             Home
# 9540    541890   2023-01-19   09:00:00  10:00:00             Home
# 9541    542077   2023-01-30   14:30:00  15:20:00       Telehealth
# 9542    542122   2023-01-30   13:00:00  14:00:00             Home
#
#        SERVICE DELIVERY          ADD_USER            ADD_DATE  \
# 0     Service Delivered         LEECAROL1 2022-01-21 17:54:45
# 1     Service Delivered         LEECAROL1 2022-02-16 05:29:12
# 2     Service Delivered  MILLARDCATHERINE 2022-01-24 14:18:29
# 3     Service Delivered       HEMELKATIE1 2022-01-18 10:39:51
# 4     Service Delivered        JONESMEGAN 2022-01-12 13:46:48
# ...                 ...               ...                 ...
# 9538  Service Delivered           WESTAMY 2023-01-12 17:55:59
# 9539  Service Delivered           WESTAMY 2023-01-20 16:11:04
# 9540  Service Delivered           WESTAMY 2023-01-20 10:23:05
# 9541  Service Delivered   FANELLASAMANTHA 2023-01-30 15:21:59
# 9542  Service Delivered        QUINNEMILY 2023-02-02 21:54:53
#
#      IFSP Teaming ID name                         Agency Name Agency Type  \
# 0             IEP Meeting  Siskin Children's Institute (EIRA)        EIRA
# 1                Co-Visit  Siskin Children's Institute (EIRA)        EIRA
# 2             IEP Meeting  Siskin Children's Institute (EIRA)        EIRA
# 3             IEP Meeting                               LTVEC        EIRA
# 4            IFSP Meeting             First Steps, Inc (EIRA)        EIRA
# ...                   ...                                 ...         ...
# 9538             Co-Visit                  Kid's Putnam, Inc.        EIRA
# 9539             Co-Visit                  Kid's Putnam, Inc.        EIRA
# 9540             Co-Visit                  Kid's Putnam, Inc.        EIRA
# 9541         IFSP Meeting           Pediatric Language Clinic        EIRA
# 9542             Co-Visit  Little Folks Arc of Washington Co.        EIRA
#
#                             Service Name
# 0     Dev. Therapy Prof - Home/Community
# 1     Dev. Therapy Prof - Home/Community
# 2     Dev. Therapy Prof - Home/Community
# 3     Dev. Therapy Prof - Home/Community
# 4     Dev. Therapy Prof - Home/Community
# ...                                  ...
# 9538  Dev. Therapy Prof - Home/Community
# 9539  Dev. Therapy Prof - Home/Community
# 9540  Dev. Therapy Prof - Home/Community
# 9541  Dev. Therapy Prof - Home/Community
# 9542  Dev. Therapy Prof - Home/Community
#
# [9532 rows x 12 columns]

# %%
q1_dfb = q2_df['IFSP Teaming ID name'].value_counts(normalize=True) * 100
q1_dfb.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 3 entries, IFSP Meeting to IEP Meeting
# Series name: IFSP Teaming ID name
# Non-Null Count  Dtype
# --------------  -----
# 3 non-null      float64
# dtypes: float64(1)
# memory usage: 48.0+ bytes

# %%
q1_dfb1 = pd.DataFrame({'meeting type':q1_dfb.index, 'frequency':q1_dfb.values})
q1_dfb1
# Out:
#    meeting type  frequency
# 0  IFSP Meeting  50.524549
# 1      Co-Visit  42.876626
# 2   IEP Meeting   6.598825

# %%
sns.barplot(data=q1_dfb1, x="meeting type", y="frequency")
# Out:
# <AxesSubplot:xlabel='meeting type', ylabel='frequency'>

# %% [markdown]
# 1B. Co-Visits happen about 43% of the time with no filtering. Nothing has changed with filtering for services actually delivered.

# %% [markdown]
# 4. In what setting do co-visits typically occur?

# %%
q4_df = q1_df2['SERVICE_SETTING'].value_counts(normalize=True) * 100
q4_df
# Out:
# Home               47.117727
# Community-based    20.622463
# Telehealth         19.675237
# Other              12.584574
# Name: SERVICE_SETTING, dtype: float64

# %%
q4_df1 = pd.DataFrame({'setting':q4_df.index, 'frequency':q4_df.values})
q4_df1
# Out:
#            setting  frequency
# 0             Home  47.117727
# 1  Community-based  20.622463
# 2       Telehealth  19.675237
# 3            Other  12.584574

# %%
q1_df1['IFSP Teaming ID name'].value_counts(normalize=True) * 100
# Out:
# Co-Visit    100.0
# Name: IFSP Teaming ID name, dtype: float64

# %% [markdown]
# home is where co-visits occur most frequently.

# %%
sns.barplot(data=q4_df1, x="setting", y="frequency")
# Out:
# <AxesSubplot:xlabel='setting', ylabel='frequency'>

# %%
over_6 = q1_df2.groupby(['CHILD_ID']).size()
over_6_sort = over_6.sort_values(ascending=False)
over_6_real = len(over_6_sort.loc[lambda x : x > 6])
over_6_real
# Out:
# 86

# %%
over_6_ids = over_6_sort.loc[lambda x : x > 6]
over_6_ids_df = pd.DataFrame({'CHILD_ID':over_6_ids.index, 'number of co-visits':over_6_ids.values})
over_6_ids_list = over_6_ids_df['CHILD_ID'].tolist()
over_6_df = q1_df2[q1_df2['CHILD_ID'].isin(over_6_ids_list)]
over_6_df_new = over_6_df[over_6_df.groupby('CHILD_ID').cumcount() > 5]
over_6_df_new['month'] = pd.DatetimeIndex(over_6_df_new['SERVICE_DATE']).month
over_6_df_new
# Out:
# C:\Users\KMGre\AppData\Local\Temp\ipykernel_7068\77036437.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   over_6_df_new['month'] = pd.DatetimeIndex(over_6_df_new['SERVICE_DATE']).month
#       CHILD_ID SERVICE_DATE START_TIME  END_TIME  SERVICE_SETTING  \
# 69      463637   2022-01-27   11:30:00  12:30:00             Home
# 70      463637   2022-02-10   11:30:00  12:30:00             Home
# 71      463637   2022-02-17   11:30:00  12:30:00             Home
# 72      463637   2022-02-24   11:30:00  12:30:00             Home
# 73      463637   2022-03-03   11:30:00  12:30:00             Home
# ...        ...          ...        ...       ...              ...
# 9053    530003   2022-11-15   11:30:00  12:15:00             Home
# 9054    530003   2022-11-22   11:30:00  12:15:00             Home
# 9055    530003   2022-12-06   11:30:00  12:30:00             Home
# 9056    530003   2022-12-06   11:45:00  12:45:00             Home
# 9142    530583   2022-11-11   15:00:00  15:30:00  Community-based
#
#        SERVICE DELIVERY       ADD_USER            ADD_DATE  \
# 69    Service Delivered  CARDENHILLARY 2022-02-15 17:59:26
# 70    Service Delivered  CARDENHILLARY 2022-02-27 19:00:28
# 71    Service Delivered  CARDENHILLARY 2022-02-27 19:08:37
# 72    Service Delivered  CARDENHILLARY 2022-02-27 19:17:26
# 73    Service Delivered  CARDENHILLARY 2022-04-12 22:53:28
# ...                 ...            ...                 ...
# 9053  Service Delivered     LICHTSTACY 2022-11-27 21:40:16
# 9054  Service Delivered     LICHTSTACY 2022-11-27 21:43:13
# 9055  Service Delivered     LICHTSTACY 2022-12-09 17:14:21
# 9056  Service Delivered      OTISCATHY 2023-01-01 11:02:11
# 9142  Service Delivered   TAYLORKAISEY 2022-11-13 20:26:31
#
#      IFSP Teaming ID name                              Agency Name  \
# 69               Co-Visit       LeBonheur EI & Dev (LEAD) (vendor)
# 70               Co-Visit       LeBonheur EI & Dev (LEAD) (vendor)
# 71               Co-Visit       LeBonheur EI & Dev (LEAD) (vendor)
# 72               Co-Visit       LeBonheur EI & Dev (LEAD) (vendor)
# 73               Co-Visit       LeBonheur EI & Dev (LEAD) (vendor)
# ...                   ...                                      ...
# 9053             Co-Visit  Therapeutic Rehab Services - Cathy Otis
# 9054             Co-Visit  Therapeutic Rehab Services - Cathy Otis
# 9055             Co-Visit  Therapeutic Rehab Services - Cathy Otis
# 9056             Co-Visit  Therapeutic Rehab Services - Cathy Otis
# 9142             Co-Visit   Therapy & Learning Center, Inc. (EIRA)
#
#       Agency Type                        Service Name  month
# 69    Independent                Occupational Therapy      1
# 70    Independent                Occupational Therapy      2
# 71    Independent                Occupational Therapy      2
# 72    Independent                Occupational Therapy      2
# 73    Independent                Occupational Therapy      3
# ...           ...                                 ...    ...
# 9053  Independent                    Physical Therapy     11
# 9054  Independent                    Physical Therapy     11
# 9055  Independent                    Physical Therapy     12
# 9056  Independent                Occupational Therapy     12
# 9142         EIRA  Dev. Therapy Prof - Home/Community     11
#
# [559 rows x 13 columns]

# %%
months = over_6_df_new['month'].value_counts()
months_df = pd.DataFrame({'month':months.index, 'number of co-visits':months.values})
months_df
# Out:
#     month  number of co-visits
# 0       6                   71
# 1       5                   65
# 2      11                   65
# 3       4                   54
# 4      12                   53
# 5       8                   51
# 6       3                   48
# 7       7                   48
# 8       9                   37
# 9      10                   37
# 10      2                   26
# 11      1                    4

# %%
sns.set_theme()
sns.barplot(data=months_df, x='month', y='number of co-visits',palette=["#B1301F", "#EF412A", "#343434", "#777776", "#C7CAD5", "#7099E9", "#415A8C", "#161616"])
# Out:
# <AxesSubplot:xlabel='month', ylabel='number of co-visits'>

# %%
setting_df = over_6_df_new['SERVICE_SETTING'].value_counts(normalize=True) * 100
setting_df
# Out:
# Home               64.758497
# Other              15.026834
# Community-based    11.449016
# Telehealth          8.765653
# Name: SERVICE_SETTING, dtype: float64

# %%
setting_df1 = pd.DataFrame({'setting':setting_df.index, 'frequency':setting_df.values})
setting_df1
# Out:
#            setting  frequency
# 0             Home  64.758497
# 1            Other  15.026834
# 2  Community-based  11.449016
# 3       Telehealth   8.765653

# %%
data = [63.4, 14.9, 12.5, 9.1]
labels = ['Home', 'Other', 'Community-based', 'Telehealth']

sns.set_theme()
colors1 = sns.set_palette(sns.color_palette(colors))


plt.pie(data, labels = labels, colors = colors1, autopct='%.0f%%', startangle=90)
plt.show()

# %%
services = over_6_df_new['Service Name'].value_counts()
services_df = pd.DataFrame({'Service type':services.index, 'Number of Co-Visits':services.values})
services_df
# Out:
#                          Service type  Number of Co-Visits
# 0                Occupational Therapy                  144
# 1                      Speech Therapy                  109
# 2  Dev. Therapy Prof - Home/Community                  107
# 3                    Physical Therapy                   94
# 4                 Dev. Therapy - BCBA                   64
# 5           Dev. Therapy Center-Based                   23
# 6          Physical Therapy Assistant                   12
# 7   Evaluation - Occupational Therapy                    3
# 8                     Vision Services                    2
# 9         Eval/Assess - Developmental                    1

# %%
sns.set_theme()
sns.barplot(data=services_df, x='Number of Co-Visits', y='Service type',palette=["#B1301F", "#EF412A", "#343434", "#777776", "#C7CAD5", "#7099E9", "#415A8C", "#161616"])
# Out:
# <AxesSubplot:xlabel='Number of Co-Visits', ylabel='Service type'>

# %%
over_6_df_new['Agency Type'].value_counts(normalize=True) * 100
# Out:
# Independent    73.881932
# EIRA           26.118068
# Name: Agency Type, dtype: float64

# %%
over_6_df_new['Agency Name'].value_counts(normalize=True) * 100
# Out:
# LeBonheur EI & Dev (LEAD) (vendor)                    54.561717
# LeBonheur EI & Dev (LEAD) (EIRA)                      12.164580
# Cleveland TN Hosp dba Tennova Healthcare-Cleveland     8.050089
# Shelby Residential & Voc Svcs(SRVS) (EIRA)             7.155635
# Erlanger Health Care System/TC Thompson's Children     5.366726
# Therapeutic Rehab Services - Cathy Otis                4.472272
# Kid's Putnam, Inc.                                     1.788909
# Therapy & Learning Center, Inc. (EIRA)                 1.610018
# Rehab At Your Place (EIRA)                             0.894454
# Feltz Therapy Services, LLC                            0.715564
# Physical Therapy Services, PA (EIRA)                   0.536673
# Signal Centers, Inc.                                   0.536673
# Siskin Children's Institute (EIRA)                     0.536673
# KF Pediatric Therapy                                   0.536673
# WAVES, Inc.                                            0.357782
# Heightened Potential Co                                0.178891
# BEST (Blind-Visually Impaired Early Svcs Tn)           0.178891
# Project Memphis-University of Memphis (EIRA)           0.178891
# Infant Stimulation Program - UT Martin                 0.178891
# Name: Agency Name, dtype: float64

# %%
over_6_df_new['ADD_USER'].value_counts(normalize=True) * 100
# Out:
# REDDMISSY         15.384615
# PULLIAMAMY        11.449016
# CALLICUTTJULIE     9.302326
# SOSEBEEJULIE1      7.692308
# OLIVERCIARA        6.618962
#                     ...
# DELAPCARAGN        0.178891
# RODGERSRENIKA      0.178891
# FORTNERTORI        0.178891
# CORDELLASHLEY      0.178891
# TAYLORKAISEY       0.178891
# Name: ADD_USER, Length: 64, dtype: float64

# %%
time_df = compiled_ifsp_df.groupby(['SERVICE_DATE']).size()
time_df_sort = time_df.sort_values(ascending=False)
time_df_real = len(time_df_sort.loc[lambda x : x > 1])


time_df_ids = time_df_sort.loc[lambda x : x > 1]
time_df_ids_df = pd.DataFrame({'SERVICE_DATE':time_df_ids.index, 'number of times':time_df_ids.values})
time_ids_list = time_df_ids_df['SERVICE_DATE'].tolist()
time_df_new = compiled_ifsp_df[compiled_ifsp_df['SERVICE_DATE'].isin(time_ids_list)]
new_time_df = time_df_new[time_df_new['IFSP Teaming ID name'] != 'Co-Visit']
new_time_df
# Out:
#       CHILD_ID SERVICE_DATE START_TIME  END_TIME  SERVICE_SETTING  \
# 0       457136   2022-01-21   09:30:00  10:30:00  Community-based
# 2       457585   2022-01-24   08:30:00  09:30:00       Telehealth
# 3       457852   2022-01-12   14:00:00  15:00:00  Community-based
# 4       458051   2022-01-12   12:00:00  13:00:00       Telehealth
# 5       458230   2022-01-21   15:30:00  16:30:00       Telehealth
# ...        ...          ...        ...       ...              ...
# 9522    539488   2023-01-09   16:00:00  17:00:00             Home
# 9531    539943   2023-01-10   15:00:00  16:00:00             Home
# 9535    540631   2023-01-04   03:30:00  04:30:00             Home
# 9536    540668   2023-01-20   09:00:00  09:30:00       Telehealth
# 9541    542077   2023-01-30   14:30:00  15:20:00       Telehealth
#
#        SERVICE DELIVERY             ADD_USER            ADD_DATE  \
# 0     Service Delivered            LEECAROL1 2022-01-21 17:54:45
# 2     Service Delivered     MILLARDCATHERINE 2022-01-24 14:18:29
# 3     Service Delivered          HEMELKATIE1 2022-01-18 10:39:51
# 4     Service Delivered           JONESMEGAN 2022-01-12 13:46:48
# 5     Service Delivered       BROWNSTEPHANIE 2022-01-26 21:04:15
# ...                 ...                  ...                 ...
# 9522  Service Delivered  HUFFSTETTLERMELISSA 2023-01-10 10:11:41
# 9531  Service Delivered  HUFFSTETTLERMELISSA 2023-01-10 17:18:16
# 9535  Service Delivered  HUFFSTETTLERMELISSA 2023-01-04 17:26:55
# 9536  Service Delivered      RICHARDSONMARY2 2023-01-23 16:14:37
# 9541  Service Delivered      FANELLASAMANTHA 2023-01-30 15:21:59
#
#      IFSP Teaming ID name                                 Agency Name  \
# 0             IEP Meeting          Siskin Children's Institute (EIRA)
# 2             IEP Meeting          Siskin Children's Institute (EIRA)
# 3             IEP Meeting                                       LTVEC
# 4            IFSP Meeting                     First Steps, Inc (EIRA)
# 5            IFSP Meeting  Sunshine Early Intervention - Knox Cty ARC
# ...                   ...                                         ...
# 9522         IFSP Meeting  Sunshine Early Intervention - Knox Cty ARC
# 9531         IFSP Meeting  Sunshine Early Intervention - Knox Cty ARC
# 9535         IFSP Meeting  Sunshine Early Intervention - Knox Cty ARC
# 9536         IFSP Meeting                   Expanding Horizons - ETSU
# 9541         IFSP Meeting                   Pediatric Language Clinic
#
#      Agency Type                        Service Name
# 0           EIRA  Dev. Therapy Prof - Home/Community
# 2           EIRA  Dev. Therapy Prof - Home/Community
# 3           EIRA  Dev. Therapy Prof - Home/Community
# 4           EIRA  Dev. Therapy Prof - Home/Community
# 5           EIRA  Dev. Therapy Prof - Home/Community
# ...          ...                                 ...
# 9522        EIRA  Dev. Therapy Prof - Home/Community
# 9531        EIRA  Dev. Therapy Prof - Home/Community
# 9535        EIRA  Dev. Therapy Prof - Home/Community
# 9536        EIRA  Dev. Therapy Prof - Home/Community
# 9541        EIRA  Dev. Therapy Prof - Home/Community
#
# [5445 rows x 12 columns]

# %% [markdown]
# gb = compiled_ifsp_df.groupby("CHILD_ID")
# set.intersection(*[set(group["SERVICE_DATE"]) for name, group in gb])
#
# from itertools import combinations
#
# pairs = list(combinations(compiled_ifsp_df["CHILD_ID"].unique(), 2))
#
#
#
# for subset in pairs:
#     _df = compiled_ifsp_df[compiled_ifsp_df["CHILD_ID"].isin(subset)]
#
# _df

# %%
over_6_df['SERVICE_SETTING'].value_counts(normalize=True) * 100
# Out:
# Home               62.046512
# Other              14.139535
# Telehealth         13.674419
# Community-based    10.139535
# Name: SERVICE_SETTING, dtype: float64

# %%
only_6 = len(over_6_sort.loc[lambda x : x == 6])
only_6
# Out:
# 30

# %%
under_6 = len(over_6_sort.loc[lambda x : x < 6])
under_6
# Out:
# 1385

# %%
no_visits = len(over_6_sort.loc[lambda x : x == 0])
no_visits
# Out:
# 0

# %%
data = [['over 6', over_6_real], ['exactly 6', only_6], ['under 6', under_6]]
df = pd.DataFrame(data, columns=['co-visits', 'number of co-visits'])
df
# Out:
#    co-visits  number of co-visits
# 0     over 6                   86
# 1  exactly 6                   30
# 2    under 6                 1385

# %%
sns.barplot(data=df, x="co-visits", y="number of co-visits")
# Out:
# <AxesSubplot:xlabel='co-visits', ylabel='number of co-visits'>

# %%
q1_df1['Agency Type'].value_counts(normalize=True) * 100
# Out:
# EIRA           65.426964
# Independent    34.573036
# Name: Agency Type, dtype: float64

# %%
q1_df1['Agency Name'].value_counts(normalize=True) * 100
# Out:
# LeBonheur EI & Dev (LEAD) (vendor)                   22.045510
# LeBonheur EI & Dev (LEAD) (EIRA)                      8.319060
# Shelby Residential & Voc Svcs(SRVS) (EIRA)            5.676535
# Therapy & Learning Center, Inc. (EIRA)                5.285050
# Kid's Putnam, Inc.                                    5.187179
#                                                        ...
# Words for Life Speech & Language Center, LLC          0.024468
# Jeannine Couvertiere, SLP Services                    0.024468
# Choice Medical Inc / Choice Orthotics Prosthetics     0.024468
# Blount Memorial Hospital                              0.024468
# Therapy.Works LLC                                     0.024468
# Name: Agency Name, Length: 76, dtype: float64

# %%
q1_df2['Service Name'].value_counts()
# Out:
# Dev. Therapy Prof - Home/Community               2397
# Occupational Therapy                              501
# Speech Therapy                                    425
# Physical Therapy                                  307
# Dev. Therapy - BCBA                               133
# Dev. Therapy Center-Based                         102
# Vision Services                                    60
# Eval/Assess - Developmental                        52
# Physical Therapy Assistant                         32
# Evaluation - Occupational Therapy                  26
# Evaluation - Speech Therapy                        15
# Evaluation - Physical Therapy                      15
# Dev. Therapy – Registered Behavior Tech (RBT)       9
# Dev. Therapy - Behavior                             4
# Assistive Technology                                3
# Evaluation - BCBA Developmental Therapy             3
# Speech Therapy-Group                                1
# Evaluation/Assessment - Vision                      1
# Occupational Therapy Assistant                      1
# Name: Service Name, dtype: int64

# %%
q4_df2 = compiled_ifsp_df[compiled_ifsp_df["SERVICE DELIVERY"] != 'Service Delivered']
q4_df2
# Out:
#       CHILD_ID SERVICE_DATE START_TIME END_TIME SERVICE_SETTING  \
# 238     469545   2022-03-22        NaN      NaN             NaN
# 1223    481717   2022-05-20        NaN      NaN             NaN
# 3774    500266   2022-02-18        NaN      NaN             NaN
# 6054    511399   2022-10-17        NaN      NaN             NaN
# 6115    511559   2022-07-04        NaN      NaN            Home
# 6718    513855   2022-05-30        NaN      NaN             NaN
# 7474    518376   2022-12-27        NaN      NaN             NaN
# 7739    520343   2022-03-24        NaN      NaN             NaN
# 7846    521207   2022-07-20        NaN      NaN             NaN
# 8546    526490   2022-06-29        NaN      NaN             NaN
# 8637    527044   2022-11-29        NaN      NaN             NaN
#
#              SERVICE DELIVERY          ADD_USER            ADD_DATE  \
# 238     Absence Due to Family      PARKERDIANA1 2022-03-24 21:20:38
# 1223           Family No Show     SANDERSBROOKE 2022-05-21 01:58:09
# 3774    Absence Due to Family  CARDENASJESSICA1 2022-02-22 10:50:57
# 6054  Absence Due to Provider       CONWAYPEGGY 2022-10-17 13:44:23
# 6115  Absence Due to Provider         REDDMISSY 2023-01-17 22:28:51
# 6718  Absence Due to Provider       CONWAYPEGGY 2022-05-30 15:44:21
# 7474    Absence Due to Family        LAVOLLAMY1 2022-12-29 16:58:06
# 7739    Absence Due to Family      POWERSCARRIE 2022-03-24 15:41:27
# 7846    Absence Due to Family        REEDKATIA1 2022-07-26 03:46:15
# 8546    Absence Due to Family       HOYOSSANDRA 2022-07-06 13:18:45
# 8637           Family No Show    HAMILTONHANNAH 2022-11-29 15:49:04
#
#      IFSP Teaming ID name                                 Agency Name  \
# 238          IFSP Meeting          Siskin Children's Institute (EIRA)
# 1223         IFSP Meeting        Physical Therapy Services, PA (EIRA)
# 3774          IEP Meeting  Shelby Residential & Voc Svcs(SRVS) (EIRA)
# 6054             Co-Visit                         Emory Valley Center
# 6115             Co-Visit          LeBonheur EI & Dev (LEAD) (vendor)
# 6718             Co-Visit                         Emory Valley Center
# 7474         IFSP Meeting                         Emory Valley Center
# 7739         IFSP Meeting      Infant Stimulation Program - UT Martin
# 7846             Co-Visit                  Rehab At Your Place (EIRA)
# 8546          IEP Meeting                                       LTVEC
# 8637          IEP Meeting            LeBonheur EI & Dev (LEAD) (EIRA)
#
#       Agency Type                        Service Name
# 238          EIRA  Dev. Therapy Prof - Home/Community
# 1223         EIRA  Dev. Therapy Prof - Home/Community
# 3774         EIRA  Dev. Therapy Prof - Home/Community
# 6054         EIRA  Dev. Therapy Prof - Home/Community
# 6115  Independent                Occupational Therapy
# 6718         EIRA  Dev. Therapy Prof - Home/Community
# 7474         EIRA  Dev. Therapy Prof - Home/Community
# 7739         EIRA  Dev. Therapy Prof - Home/Community
# 7846         EIRA  Dev. Therapy Prof - Home/Community
# 8546         EIRA  Dev. Therapy Prof - Home/Community
# 8637         EIRA  Dev. Therapy Prof - Home/Community

# %%
result = pd.concat([q4_df2, all_child_df], axis=1, join="inner")
result
# Out:
#       CHILD_ID SERVICE_DATE START_TIME END_TIME SERVICE_SETTING  \
# 238     469545   2022-03-22        NaN      NaN             NaN
# 1223    481717   2022-05-20        NaN      NaN             NaN
# 3774    500266   2022-02-18        NaN      NaN             NaN
# 6054    511399   2022-10-17        NaN      NaN             NaN
# 6115    511559   2022-07-04        NaN      NaN            Home
# 6718    513855   2022-05-30        NaN      NaN             NaN
# 7474    518376   2022-12-27        NaN      NaN             NaN
# 7739    520343   2022-03-24        NaN      NaN             NaN
# 7846    521207   2022-07-20        NaN      NaN             NaN
# 8546    526490   2022-06-29        NaN      NaN             NaN
# 8637    527044   2022-11-29        NaN      NaN             NaN
#
#              SERVICE DELIVERY          ADD_USER            ADD_DATE  \
# 238     Absence Due to Family      PARKERDIANA1 2022-03-24 21:20:38
# 1223           Family No Show     SANDERSBROOKE 2022-05-21 01:58:09
# 3774    Absence Due to Family  CARDENASJESSICA1 2022-02-22 10:50:57
# 6054  Absence Due to Provider       CONWAYPEGGY 2022-10-17 13:44:23
# 6115  Absence Due to Provider         REDDMISSY 2023-01-17 22:28:51
# 6718  Absence Due to Provider       CONWAYPEGGY 2022-05-30 15:44:21
# 7474    Absence Due to Family        LAVOLLAMY1 2022-12-29 16:58:06
# 7739    Absence Due to Family      POWERSCARRIE 2022-03-24 15:41:27
# 7846    Absence Due to Family        REEDKATIA1 2022-07-26 03:46:15
# 8546    Absence Due to Family       HOYOSSANDRA 2022-07-06 13:18:45
# 8637           Family No Show    HAMILTONHANNAH 2022-11-29 15:49:04
#
#      IFSP Teaming ID name                                 Agency Name  \
# 238          IFSP Meeting          Siskin Children's Institute (EIRA)
# 1223         IFSP Meeting        Physical Therapy Services, PA (EIRA)
# 3774          IEP Meeting  Shelby Residential & Voc Svcs(SRVS) (EIRA)
# 6054             Co-Visit                         Emory Valley Center
# 6115             Co-Visit          LeBonheur EI & Dev (LEAD) (vendor)
# 6718             Co-Visit                         Emory Valley Center
# 7474         IFSP Meeting                         Emory Valley Center
# 7739         IFSP Meeting      Infant Stimulation Program - UT Martin
# 7846             Co-Visit                  Rehab At Your Place (EIRA)
# 8546          IEP Meeting                                       LTVEC
# 8637          IEP Meeting            LeBonheur EI & Dev (LEAD) (EIRA)
#
#       Agency Type                        Service Name POE  Child ID  \
# 238          EIRA  Dev. Therapy Prof - Home/Community  ET    488999
# 1223         EIRA  Dev. Therapy Prof - Home/Community  ET    508469
# 3774         EIRA  Dev. Therapy Prof - Home/Community  GN    513592
# 6054         EIRA  Dev. Therapy Prof - Home/Community  NW    500951
# 6115  Independent                Occupational Therapy  NW    520257
# 6718         EIRA  Dev. Therapy Prof - Home/Community  SC    512342
# 7474         EIRA  Dev. Therapy Prof - Home/Community  SC    499507
# 7739         EIRA  Dev. Therapy Prof - Home/Community  SC    499000
# 7846         EIRA  Dev. Therapy Prof - Home/Community  SE    516515
# 8546         EIRA  Dev. Therapy Prof - Home/Community  SE    514988
# 8637         EIRA  Dev. Therapy Prof - Home/Community  SW    518868
#
#      Referral Date  Exit Date
# 238     2020-09-08        NaT
# 1223    2021-08-04        NaT
# 3774    2021-10-28        NaT
# 6054    2021-07-07 2022-02-15
# 6115    2022-01-25        NaT
# 6718    2021-10-06        NaT
# 7474    2021-03-11        NaT
# 7739    2021-03-03        NaT
# 7846    2021-12-09        NaT
# 8546    2021-11-18        NaT
# 8637    2022-01-10        NaT

# %%
result['POE'].value_counts(normalize=True) * 100
# Out:
# SC    27.272727
# ET    18.181818
# NW    18.181818
# SE    18.181818
# GN     9.090909
# SW     9.090909
# Name: POE, dtype: float64

# %%
result['Service Name'].value_counts(normalize=True) * 100
# Out:
# Dev. Therapy Prof - Home/Community    90.909091
# Occupational Therapy                   9.090909
# Name: Service Name, dtype: float64

# %%
data_xlsx_path = '../data/TEIS_IFSP_Teaming_Jan_2022-_Jan_2023.xlsx'
ifsp_teaming_df = pd.read_excel(data_xlsx_path, sheet_name='Compiled_IFSP Teaming')

all_covists_df = ifsp_teaming_df[ifsp_teaming_df["IFSP Teaming ID name"] == 'Co-Visit']
successful_covists_df = all_covists_df[all_covists_df["SERVICE DELIVERY"] == 'Service Delivered']
successful_covists_in_2022_df = successful_covists_df[successful_covists_df['SERVICE_DATE'] < '2023-01-01']

n_covisits_per_child = successful_covists_in_2022_df.groupby(['CHILD_ID']).size()
n_covisits_per_child_desc = n_covisits_per_child.sort_values(ascending=False)

n_children_receiving_more_than_6_covisits_per_year = len(n_covisits_per_child_desc.loc[lambda x : x > 6])

n_children_receiving_6_covisits_per_year = len(n_covisits_per_child_desc.loc[lambda x : x == 6])
children_receiving_6_covisits_per_year = n_covisits_per_child_desc.loc[lambda x : x == 6]

print(f'Initial Number of total co-visits: {len(all_covists_df)}')
print(f'Number of total co-visits: {len(successful_covists_df)}')
print(f'The number children receiving co-visits: {len(n_covisits_per_child)}')
print(f'Number of children receiving 6 co-visits per year: {n_children_receiving_6_covisits_per_year}')
print(f'Number of children receiving more than 6 co-visits per year: {n_children_receiving_more_than_6_covisits_per_year}')
# Out:
# Initial Number of total co-visits: 4091
# Number of total co-visits: 4087
# The number children receiving co-visits: 1501
# Number of children receiving 6 co-visits per year: 30
# Number of children receiving more than 6 co-visits per year: 86

# %%
successful_covists_in_2022_df
# Out:
#       CHILD_ID SERVICE_DATE START_TIME  END_TIME  SERVICE_SETTING  \
# 1       457136   2022-02-15   14:00:00  15:00:00  Community-based
# 6       458850   2022-02-15   14:00:00  14:30:00       Telehealth
# 7       458851   2022-02-15   14:15:00  14:45:00       Telehealth
# 8       459167   2022-01-26   09:30:00  10:00:00       Telehealth
# 9       459167   2022-01-26   09:00:00  10:00:00       Telehealth
# ...        ...          ...        ...       ...              ...
# 9504    537193   2022-12-20   11:00:00  12:00:00             Home
# 9505    537193   2022-12-20   11:00:00  12:00:00             Home
# 9527    539820   2022-12-12   16:25:00  17:10:00  Community-based
# 9528    539820   2022-12-19   09:20:00  10:00:00  Community-based
# 9534    540001   2022-12-16   13:30:00  14:00:00             Home
#
#        SERVICE DELIVERY          ADD_USER            ADD_DATE  \
# 1     Service Delivered         LEECAROL1 2022-02-16 05:29:12
# 6     Service Delivered       BUCKCYNTHIA 2022-02-15 18:07:38
# 7     Service Delivered       BUCKCYNTHIA 2022-02-15 18:08:54
# 8     Service Delivered    HINESKONSTANCE 2022-01-26 11:08:06
# 9     Service Delivered    GLASSKATHERINE 2022-02-02 11:57:55
# ...                 ...               ...                 ...
# 9504  Service Delivered         THEOBALDD 2022-12-20 20:54:26
# 9505  Service Delivered    JOHNSTONNICOLE 2022-12-23 11:41:04
# 9527  Service Delivered  SCHNEIDERKATHRYN 2022-12-16 17:46:00
# 9528  Service Delivered  SCHNEIDERKATHRYN 2022-12-21 14:25:30
# 9534  Service Delivered     SCOTTKRISTINA 2022-12-16 16:25:15
#
#      IFSP Teaming ID name                                        Agency Name  \
# 1                Co-Visit                 Siskin Children's Institute (EIRA)
# 6                Co-Visit               Physical Therapy Services, PA (EIRA)
# 7                Co-Visit               Physical Therapy Services, PA (EIRA)
# 8                Co-Visit                   LeBonheur EI & Dev (LEAD) (EIRA)
# 9                Co-Visit                 LeBonheur EI & Dev (LEAD) (vendor)
# ...                   ...                                                ...
# 9504             Co-Visit                            Heightened Potential Co
# 9505             Co-Visit                                              LTVEC
# 9527             Co-Visit                 Little Folks Arc of Washington Co.
# 9528             Co-Visit                 Little Folks Arc of Washington Co.
# 9534             Co-Visit  Support Solutions of the Mid-South (CS Patterson)
#
#       Agency Type                        Service Name
# 1            EIRA  Dev. Therapy Prof - Home/Community
# 6            EIRA  Dev. Therapy Prof - Home/Community
# 7            EIRA  Dev. Therapy Prof - Home/Community
# 8            EIRA          Physical Therapy Assistant
# 9     Independent                      Speech Therapy
# ...           ...                                 ...
# 9504  Independent                Occupational Therapy
# 9505         EIRA  Dev. Therapy Prof - Home/Community
# 9527         EIRA  Dev. Therapy Prof - Home/Community
# 9528         EIRA  Dev. Therapy Prof - Home/Community
# 9534         EIRA  Dev. Therapy Prof - Home/Community
#
# [3695 rows x 12 columns]

# %%
successful_covists_in_2022_df['SERVICE_SETTING'].value_counts(normalize=True) * 100
# Out:
# Home               47.117727
# Community-based    20.622463
# Telehealth         19.675237
# Other              12.584574
# Name: SERVICE_SETTING, dtype: float64

# %%
data = [47, 12, 21, 20]
labels = ['Home', 'Other', 'Community-based', 'Telehealth']



sns.set_theme()
colors1 = sns.set_palette(sns.color_palette(colors))
#plt.pie(data, labels = labels, colors = colors1, autopct='%.0f%%')
#plt.show()

plt.pie(
    data, 
    labels=labels,
    autopct='%.0f%%',
    colors=colors1,
    startangle=90,
)
plt.show()
